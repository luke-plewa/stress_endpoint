# %%
# %matplotlib inline
from data_vis import load, run

# %% [markdown]
# In a Support Vector Machine, we're interested in drawing hyperlines to identify where we can draw linear lines between two sets of a data. The hyperdimensions these lines exist in is determined by the features of the dataset. Each feature defines a dimension, and the comparison between two features can be represented in a two dimensional state.
#
# Parallel coordinates can help visualize this. The goal here is to identify multiple features which we can clump together to create a particularly accurate hyperline. In this way, we can remove unhelpful features and only include helpful features.

# %%
load()

# %%
# absolute sorts the deltas by absolute value,
# giving us the features in order of highest to lowest difference by average

run("absolute")
# Out:
# ['sdhr', 'std_dev', 'median', 'max', 'rmsdd', 'mean', 'sdsd', 'min', 'outlier', 'nn_50']

# %%
# normal gives us the sorting by delta averages,
# starting with red on bottom and ending up with blue on top
run("normal")
# Out:
# ['min', 'outlier', 'nn_50', 'mean', 'sdsd', 'rmsdd', 'max', 'median', 'std_dev', 'sdhr']

# %%
# sorts the parallel coordinates in increasing order based on the average SCD class normalized feature values
run("scd")
# Out:
# ['min', 'outlier', 'nn_50', 'mean', 'sdsd', 'rmsdd', 'max', 'median', 'std_dev', 'sdhr']

# %%
# sorts the parallel coordinates in increasing order based on the average normal sinus rhythm class normalized feature values
run("norm")
# Out:
# ['nn_50', 'std_dev', 'max', 'median', 'rmsdd', 'mean', 'sdsd', 'min', 'outlier', 'sdhr']

# %%
# The second, optional parameter is whether or not to normalize the coordinates
run("absolute", False)
# Out:
# ['sdhr', 'std_dev', 'median', 'max', 'rmsdd', 'mean', 'sdsd', 'min', 'outlier', 'nn_50']
